# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("./시도별 전출입 인구수.xlsx")

# %%
df.head()
# Out:
#    전출지별   전입지별      1970      1971      1972      1973      1974      1975  \
# 0  전출지별   전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1    전국     전국   4046536   4210164   3687938   4860418   5297969   9011440
# 2   NaN  서울특별시   1742813   1671705   1349333   1831858   2050392   3396662
# 3   NaN  부산광역시    448577    389797    362202    482061    680984    805979
# 4   NaN  대구광역시         -         -         -         -         -         -
#
#        1976      1977  ...      2008      2009      2010      2011      2012  \
# 0  이동자수 (명)  이동자수 (명)  ...  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   6773250   7397623  ...   8808256   8487275   8226594   8127195   7506691
# 2   2756510   2893403  ...   2025358   1873188   1733015   1721748   1555281
# 3    724664    785117  ...    514502    519310    519334    508043    461042
# 4         -         -  ...    409938    398626    370817    370563    348642
#
#        2013      2014      2015      2016      2017
# 0  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   7411784   7629098   7755286   7378430   7154226
# 2   1520090   1573594   1589431   1515602   1472937
# 3    478451    485710    507031    459015    439073
# 4    351873    350213    351424    328228    321182
#
# [5 rows x 50 columns]

# %%
df.tail()
# Out:
#     전출지별     전입지별  1970   1971   1972   1973   1974   1975   1976   1977  ...  \
# 320  NaN     전라북도   139    202    141    210    219    415    392    408  ...
# 321  NaN     전라남도   631    965    857    952   1133   2808   2608   2652  ...
# 322  NaN     경상북도   374    619    468    576    625   1123   1141   1004  ...
# 323  NaN     경상남도   474    479    440    571   1208   1517    863   1122  ...
# 324  NaN  제주특별자치도  9290  12427  12210  16158  19580  34221  23291  31028  ...
#
#       2008   2009   2010   2011   2012   2013   2014   2015   2016   2017
# 320    668    579    672    561    551    516    609    683    733    768
# 321   1143   1123   1002   1026    966   1001    928   1062   1127   1102
# 322    761    704    738    756    699    781    728    903    931    994
# 323   1517   1474   1324   1367   1227   1278   1223   1500   1448   1501
# 324  59564  55673  55507  59846  54280  60607  59673  59036  66444  63275
#
# [5 rows x 50 columns]

# %%
df.shape
# Out:
# (325, 50)

# %%
df.describe()
# Out:
#         전출지별     전입지별 1970 1971 1972 1973 1974 1975 1976 1977  ... 2008 2009  \
# count     19      325  325  325  325  325  325  325  325  325  ...  325  325
# unique    19       19  146  146  146  146  145  146  146  146  ...  289  289
# top     전출지별  세종특별자치시    -    -    -    -    -    -    -    -  ...    -    -
# freq       1       18  180  180  180  180  180  180  180  180  ...   35   35
#
#        2010 2011  2012  2013  2014  2015  2016 2017
# count   325  325   325   325   325   325   325  325
# unique  289  291   323   320   321   324   322  323
# top       -    -  1489  1939  2026  1468  4303  947
# freq     35   35     2     2     2     2     2    2
#
# [4 rows x 50 columns]

# %%
df = df.fillna(method='ffill')

# %%
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시') 
df_seoul = df[mask]
df_seoul = df_seoul.drop(['전출지별'], axis=1)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

# %%
sr_one = df_seoul.loc['경기도']
sr_one
# Out:
# 1970    130149
# 1971    150313
# 1972     93333
# 1973    143234
# 1974    149045
# 1975    253705
# 1976    202276
# 1977    207722
# 1978    237684
# 1979    278411
# 1980    297539
# 1981    252073
# 1982    320174
# 1983    400875
# 1984    352238
# 1985    390265
# 1986    412535
# 1987    405220
# 1988    415174
# 1989    412933
# 1990    473889
# 1991    384714
# 1992    428344
# 1993    502584
# 1994    542204
# 1995    599411
# 1996    520566
# 1997    495454
# 1998    407050
# 1999    471841
# 2000    435573
# 2001    499575
# 2002    516765
# 2003    457656
# 2004    400206
# 2005    414621
# 2006    449632
# 2007    431637
# 2008    412408
# 2009    398282
# 2010    410735
# 2011    373771
# 2012    354135
# 2013    340801
# 2014    332785
# 2015    359337
# 2016    370760
# 2017    342433
# Name: 경기도, dtype: object

# %%
plt.plot(sr_one.index, sr_one.values)

# %%
import matplotlib.font_manager as fm
print(fm.findSystemFonts(fontpaths=None, fontext='ttf'))
plt.rc('font', family='NanumGothic')
print(plt.rcParams['font.family'])
# Out:
# ['C:\\WINDOWS\\Fonts\\LSANSI.TTF', 'C:\\WINDOWS\\Fonts\\trebuc.ttf', 'C:\\WINDOWS\\Fonts\\H2GTRM.TTF', 'C:\\Windows\\Fonts\\HANBatangB.ttf', 'C:\\Windows\\Fonts\\NIAGENG.TTF', 'C:\\WINDOWS\\Fonts\\TCM_____.TTF', 'C:\\Windows\\Fonts\\verdanaz.ttf', 'C:\\WINDOWS\\Fonts\\FRAMDCN.TTF', 'C:\\Windows\\Fonts\\calibril.ttf', 'C:\\Windows\\Fonts\\segoeuiz.ttf', 'C:\\Windows\\Fonts\\ANTQUAB.TTF', 'C:\\Windows\\Fonts\\ARIALNB.TTF', 'C:\\Windows\\Fonts\\courbd.ttf', 'C:\\Windows\\Fonts\\PERTIBD.TTF', 'C:\\WINDOWS\\Fonts\\HYMPRL.TTF', 'C:\\Windows\\Fonts\\ROCK.TTF', 'C:\\WINDOWS\\Fonts\\Gabriola.ttf', 'C:\\Windows\\Fonts\\FRAHVIT.TTF', 'C:\\Windows\\Fonts\\MAIAN.TTF', 'C:\\Windows\\Fonts\\ahn_b.ttf', 'C:\\Windows\\Fonts\\BSSYM7.TTF', 'C:\\Windows\\Fonts\\LCALLIG.TTF', 'C:\\Windows\\Fonts\\seguisli.ttf', 'C:\\Windows\\Fonts\\FRADM.TTF', 'C:\\Windows\\Fonts\\LEELAWDB.TTF', 'C:\\Windows\\Fonts\\himalaya.ttf', 'C:\\Windows\\Fonts\\WINGDNG3.TTF', 'C:\\Wind
f', 'C:\\Windows\\Fonts\\HANSolM.ttf', 'C:\\Windows\\Fonts\\LTYPEBO.TTF', 'C:\\WINDOWS\\Fonts\\tahoma.ttf', 'C:\\WINDOWS\\Fonts\\HYSANB.TTF', 'C:\\Windows\\Fonts\\COLONNA.TTF', 'C:\\Windows\\Fonts\\Candaral.ttf', 'C:\\WINDOWS\\Fonts\\GARA.TTF', 'C:\\WINDOWS\\Fonts\\georgiab.ttf', 'C:\\WINDOWS\\Fonts\\HANDotumExt.ttf', 'C:\\WINDOWS\\Fonts\\LeelaUIb.ttf', 'C:\\WINDOWS\\Fonts\\H2SA1M.TTF', 'C:\\Windows\\Fonts\\YINJ05.TTF', 'C:\\WINDOWS\\Fonts\\HYCYSM.TTF', 'C:\\Windows\\Fonts\\H2MKPB.TTF', 'C:\\WINDOWS\\Fonts\\FZSong_Super.TTF', 'C:\\Windows\\Fonts\\HANCooljazzL.ttf', 'C:\\Windows\\Fonts\\YDOO08.TTF', 'C:\\Windows\\Fonts\\HANSolB.ttf', 'C:\\WINDOWS\\Fonts\\TCCEB.TTF', 'C:\\Windows\\Fonts\\comic.ttf', 'C:\\Windows\\Fonts\\verdanai.ttf', 'C:\\Windows\\Fonts\\seguihis.ttf', 'C:\\Windows\\Fonts\\ROCC____.TTF', 'C:\\Windows\\Fonts\\NanumGothicBold.ttf', 'C:\\Windows\\Fonts\\HMKBA.TTF', 'C:\\Windows\\Fonts\\malgunbd.ttf', 'C:\\WINDOWS\\Fonts\\HANYheadM.ttf', 'C:\\Windows\\Fonts\\TCM_____.TTF', 'C:\\WINDOWS\\Fonts\\segoeprb.ttf', 'C:\\Windows\\Fonts\\cambriai.ttf', 'C:\\Windows\\Fonts\\LTYPE.TTF', 'C:\\WINDOWS\\Fonts\\ENPKAV.TTF', 'C:\\WINDOWS\\Fonts\\himalaya.ttf', 'C:\\WINDOWS\\Fonts\\consola.ttf', 'C:\\WINDOWS\\Fonts\\gadugib.ttf', 'C:\\Windows\\Fonts\\ENOCRB10.TTF', 'C:\\Windows\\Fonts\\LEELAWAD.TTF', 'C:\\WINDOWS\\Fonts\\PER_____.TTF', 'C:\\Wi ...
# ['NanumGothic']

# %%
sr_one = df_seoul.loc['경기도']
# 스타일지정
plt.style.use('ggplot')

plt.figure(figsize=(14,5))
plt.plot(sr_one.index, sr_one.values)

plt.title('서울 -> 경기도 이동 수')  #차트 제목
plt.xlabel('기간')                  #x축 이름
plt.ylabel('이동 이동수')           #y축 이름
#x 축 눈금 label 회전하기
plt.xticks(rotation='50')
#x,y축 데이터를 plot 함수에 입력
plt.plot(sr_one.index, sr_one.values, marker='o', markersize=10) 
#법레 

plt.legend(labels=['서울 -> 경기'], loc='best') 
plt.show()

# %%
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
