# %%
import matplotlib.font_manager as fm
print(fm.findSystemFonts(fontpaths=None, fontext='ttf'))
plt.rc('font', family='NanumGothic')
print(plt.rcParams['font.family'])
# Out:
# ['C:\\Windows\\Fonts\\segoeprb.ttf', 'C:\\WINDOWS\\Fonts\\ntailub.ttf', 'C:\\Windows\\Fonts\\YWDA05.TTF', 'C:\\Windows\\Fonts\\ENGR.TTF', 'C:\\WINDOWS\\Fonts\\sylfaen.ttf', 'C:\\WINDOWS\\Fonts\\simsunb.ttf', 'C:\\WINDOWS\\Fonts\\ENCSCHI.TTF', 'C:\\WINDOWS\\Fonts\\\x7f\x7f\x7f\x7fEXTRABOLD.TTF', 'C:\\WINDOWS\\Fonts\\comici.ttf', 'C:\\Windows\\Fonts\\ROCKBI.TTF', 'C:\\WINDOWS\\Fonts\\LCALLIG.TTF', 'C:\\WINDOWS\\Fonts\\BOD_BLAI.TTF', 'C:\\WINDOWS\\Fonts\\RAGE.TTF', 'C:\\Windows\\Fonts\\BELL.TTF', 'C:\\WINDOWS\\Fonts\\timesi.ttf', 'C:\\Windows\\Fonts\\seguisbi.ttf', 'C:\\Windows\\Fonts\\ENS721LI.TTF', 'C:\\Windows\\Fonts\\ENOCRA.TTF', 'C:\\WINDOWS\\Fonts\\simsun.ttc', 'C:\\Windows\\Fonts\\WINGDNG3.TTF', 'C:\\Windows\\Fonts\\FRSCRIPT.TTF', 'C:\\Windows\\Fonts\\HANCooljazzB.ttf', 'C:\\Windows\\Fonts\\BOD_B.TTF', 'C:\\Windows\\Fonts\\msjhl.ttc', 'C:\\Windows\\Fonts\\ENCOBKI.TTF', 'C:\\Windows\\Fonts\\ARLRDBD.TTF', 'C:\\Windows\\Fonts\\ITCBLKAD.TTF', 'C:\\Windows\\Fonts\\constan.ttf', 'C:\\WINDOWS\\Fonts\\COOPBL.TTF', 'C:\\WINDOWS\\Fonts\\monbaiti.ttf', 'C:\\Windows\\Fonts\\calibrili.ttf', 'C:\\Windows\\Fonts\\MM.TTF', 'C:\\Windows\\Fonts\\PARCHM.TTF', 'C:\\WINDOWS\\Fonts\\CALISTB.TTF', 'C:\\WINDOWS\\Fonts\\MSUIGHUB.TTF', 'C:\\WINDOWS\\Fonts\\PER_____.TTF', 'C:\\Windows\\Fonts\\Inkfree.ttf', 'C:\\Windows\\Fonts\\CALISTB.TTF', 'C:\\Windows\\Fonts\\corbell.ttf', 'C:\\Windows\\Fonts\\ROCC____.TTF', 'C:\\WINDOWS\\Fonts\\YBLO05.TTF', 'C:\\WINDOWS\\Fonts\\ENORAT10.TTF', 'C:\\WINDOWS\\Fonts\\Candaral.ttf', 'C:\\Windows\\Fonts\\PER_____.TTF', 'C:\\WINDOWS\\Fonts\\arial.ttf', 'C:\\WINDOWS\\Fonts\\MATURASC.TTF', 'C:\\Windows\\Fonts\\LTYPEO.TTF', 'C:\\Windows\\Fonts\\YuGothR.ttc', 'C:\\Windows\\Fonts\\REFSPCL.TTF', 'C:\\WINDOWS\\Fonts\\BOD_BI.TTF', 'C:\\Windows\\Fonts\\\x7f\x7f\x7f\x7f.TTF', 'C:\\WINDOWS\\Fonts\\ITCEDSCR.TTF', 'C:\\Windows\\Fonts\\BOD_BI.TTF', 'C:\\Windows\\Fonts\\H2MKPB.TTF', 'C:\\WINDOWS\\Fonts\\NanumGothic.ttf', 'C:\\WINDOWS\\Fonts\\GILI____.TTF', 'C:\\Windows\\Fonts\\MP.TTF', 'C:\\WINDOWS\\Fonts\\PERBI___.TTF', 'C:\\Windows\\Fonts\\HMKBA.TTF', 'C:\\Windows\\Fonts\\BRLNSDB.TTF', 'C:\\WINDOWS\\Fonts\\Art.ttf', 'C:\\WINDOWS\\Fonts\\HYSNRL.TTF', 'C:\\Windows\\Fonts\\WINGDNG2.TTF', 'C:\\Windows\\Fonts\\MH.TTF', 'C:\\Windows\\Fonts\\GOTHICB.TTF', 'C:\\Windows\\Fonts\\GLECB.TTF', 'C:\\Windows\\Fonts\\SNAP____.TTF', 'C:\\WINDOWS\\Fonts\\COPRGTB.TTF', 'C:\\WINDOWS\\Fonts\\courbd.ttf', 'C:\\Windows\\Fonts\\HANDotumB.ttf', 'C:\\Windows\\Fonts\\BRITANIC.TTF', 'C:\\Windows\\Fonts\\corbelb.ttf', 'C:\\WINDOWS\\Fonts\\HANYGO250.ttf', 'C:\\WINDOWS\\Fonts\\lucon.ttf', 'C:\\WINDOWS\\Fonts\\REFSAN.TTF', 'C:\\WINDOWS\\Fonts\\SitkaB.ttc', 'C:\\WINDOWS\\Fonts\\ENBODB.TTF', 'C:\\Windows\\Fonts\\MSUIGHUB.TTF', 'C:\\Windows\\Fonts\\CENSCBK.TTF', 'C:\\Windows\\Fonts\\ariblk.ttf', 'C:\\WINDOWS\\Fonts\\Candarai.ttf', 'C:\\WINDOWS\\Fonts\\POORICH.TTF', 'C:\\Windows\\Fonts\\HANBatangExt.ttf', 'C:\\WINDOWS\\Fonts\\calibrib.ttf', 'C:\\WINDOWS\\Fonts\\YSHN05.TTF', 'C:\\Windows\\Fonts\\FRADM.TTF', 'C:\\Windows\\Fonts\\ARIALNBI.TTF', 'C:\\Windows\\Fonts\\BAUHS93.TTF', 'C:\\Windows\\Fonts\\BRUSHSCI.TTF', 'C:\\Windows\\Fonts\\PERB____.TTF', 'C:\\WINDOWS\\Fonts\\segoesc.ttf', 'C:\\Windows\\Fonts\\FRAHV.TTF', 'C:\\Windows\\Fonts\\ENGARM.TTF', 'C:\\Windows\\Fonts\\BELLI.TTF', 'C:\\Windows\\Fonts\\LSANS.TTF', 'C:\\WINDOWS\\Fonts\\segoeuii.ttf', 'C:\\WINDOWS\\Fonts\\YuGothB.ttc', 'C:\\Windows\\Fonts\\GILLUBCD.TTF', 'C:\\WINDOWS\\Fonts\\HBATANG.TTF', 'C:\\Windows\\Fonts\\HARNGTON.TTF', 'C:\\Windows\\Fonts\\corbeli.ttf', 'C:\\Windows\\Fonts\\ebrima.ttf', 'C:\\Windows\\Fonts\\BRLNSR.TTF', 'C:\\Windows\\Fonts\\msgothic.ttc', 'C:\\Windows\\Fonts\\ebrimabd.ttf', 'C:\\WINDOWS\\Fonts\\ENCR10B.TTF', 'C:\\Windows\\Fonts\\PENHL.TTF', 'C:\\WINDOWS\\Fonts\\ERASDEMI.TTF', 'C:\\WINDOWS\\Fonts\\H2GTRE.TTF', 'C:\\Windows\\Fonts\\MTCORSVA.TTF', 'C:\\WINDOWS\\Fonts\\JOKERMAN.TTF', 'C:\\WINDOWS\\Fonts\\ENGARMI.TTF', 'C:\\Windows\\Fonts\\ARIALN.TTF', 'C:\\WINDOWS\\Fonts\\YTTE08.TTF', 'C: ...
# ['NanumGothic']

# %%
# -*- coding: utf-8 -*-

# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

# Excel 데이터를 데이터프레임 변환 
df = pd.read_excel('시도별 전출입 인구수.xlsx', engine= 'openpyxl', header=0)

# 전출지별에서 누락값(NaN)을 앞 데이터로 채움 (엑셀 양식 병합 부분)
df = df.fillna(method='ffill')

# 서울에서 다른 지역으로 이동한 데이터만 추출하여 정리
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시') 
df_seoul = df[mask]
df_seoul = df_seoul.drop(['전출지별'], axis=1)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

# 서울에서 '충청남도','경상북도', '강원도', '전라남도'로 이동한 인구 데이터 값만 선택
col_years = list(map(str, range(1970, 2018)))
df_4 = df_seoul.loc[['충청남도','경상북도', '강원도', '전라남도'], col_years]
df_4 = df_4.transpose()

# 스타일 서식 지정
plt.style.use('ggplot') 

# 데이터프레임의 인덱스를 정수형으로 변경 (x축 눈금 라벨 표시)
df_4.index = df_4.index.map(int)

# 면적 그래프 그리기
df_4.plot(kind='area', stacked=False, alpha=0.2, figsize=(20, 10))

plt.title('서울 -> 타도시 인구이동', size=30)
plt.ylabel('이동 인구 수', size=20)
plt.xlabel('기간', size=20)
plt.legend(loc='best', fontsize=15)

plt.show()

# %%
# -*- coding: utf-8 -*-

# 라이브러리 불러오기
import pandas as pd
import matplotlib.pyplot as plt

# Excel 데이터를 데이터프레임 변환 
df = pd.read_excel('시도별 전출입 인구수.xlsx', engine= 'openpyxl', header=0)

# 전출지별에서 누락값(NaN)을 앞 데이터로 채움 (엑셀 양식 병합 부분)
df = df.fillna(method='ffill')

# 서울에서 다른 지역으로 이동한 데이터만 추출하여 정리
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시') 
df_seoul = df[mask]
df_seoul = df_seoul.drop(['전출지별'], axis=1)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

# 서울에서 '충청남도','경상북도', '강원도', '전라남도'로 이동한 인구 데이터 값만 선택
col_years = list(map(str, range(1970, 2018)))
df_4 = df_seoul.loc[['충청남도','경상북도', '강원도', '전라남도'], col_years]
df_4 = df_4.transpose()

# 스타일 서식 지정
plt.style.use('ggplot') 

# 데이터프레임의 인덱스를 정수형으로 변경 (x축 눈금 라벨 표시)
df_4.index = df_4.index.map(int)

# 면적 그래프 그리기
df_4.plot(kind='area', stacked=True, alpha=0.2, figsize=(20, 10)) #  True은 누적형,Furs은 각자

plt.title('서울 -> 타도시 인구이동', size=30)
plt.ylabel('이동 인구 수', size=20)
plt.xlabel('기간', size=20)
plt.legend(loc='best', fontsize=15)

plt.show()
